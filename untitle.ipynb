# %% [markdown]
# # Boolean

# %%
# vamos dizer que voce esta fazendo um codigo para registrar produtos de um sistema de estoque
"""
O objetivo deste código é criar uma lista de produtos e imprimir essa lista junto com uma variável booleana que indica se a lista é verdadeira ou não.
Nao se preocupe com a complexidade do código, apenas foque em criar uma lista de produtos e imprimir as informações de forma clara.

"""
produtos = 'Agua, sonho, feijao, macarrao, arroz, sal, oleo'
produtos2 = ['Agua', 'sonho', 'feijao', 'macarrao', 'arroz', 'sal', 'oleo']
lista_verdadeira = True

print("Lista de produtos: " + produtos)
# print("Lista de produtos (em formato de lista): " + produtos2) 
# vai dar erro pois o "produtos2" tem um valor tipo int e nao pode ser rodado a nao ser que eu declare como str
print("Lista de produtos (em formato de lista): " +str(produtos2))

print(f'produtos = "{produtos}"')
print(f'lista_verdadeira = {lista_verdadeira}')
# Out:
# Lista de produtos: Agua, sonho, feijao, macarrao, arroz, sal, oleo
# Lista de produtos (em formato de lista): ['Agua', 'sonho', 'feijao', 'macarrao', 'arroz', 'sal', 'oleo']
# produtos = "Agua, sonho, feijao, macarrao, arroz, sal, oleo"
# lista_verdadeira = True

# %% [markdown]
# # Empty Values

# %%
# None eh uma palavra reservada de Py que representa a ausencia de valor, ou seja, nao foi atribuida nenhum valor ainda.

estoque_prateleira = None
caixa_estoque = True

print(f'estoque_prateleira = {estoque_prateleira}')
print(f'caixa_estoque = {caixa_estoque}')

estoque_prateleira =input("Adicione um produto para lista do estoque: ")
print("Seu primeiro item adicionado na lista do estoque foi: " + estoque_prateleira)
print(f'estoque_prateleira = {estoque_prateleira}')
# Out:
# estoque_prateleira = None
# caixa_estoque = True
# Seu primeiro item adicionado na lista do estoque foi: Abobora
# estoque_prateleira = Abobora

# %% [markdown]
# # Arithmetric Operators

# %%
# Sao usados para performar operacos em valores

a = 2 * 5
b = 3 + 7
c = 16 - 9
d = 40 / 4

print(f'a  = {a}')
print(f'b  = {b}')
print(f'c  = {c}')
print(f'd  = {d}')
# Out:
# a  = 10
# b  = 10
# c  = 7
# d  = 10.0

# %%
# result = dividend % divisor  dividend numer being divided by divisor
# divisor, the number by witch the dividend is divided.
# result, the remainder of the dividsion.

a = 32
b = 7
c = 55

d = a % 8
e = b % 3 
f = c % 11

print(f'a = {a}')
print(f'b = {b}')
print(f'c = {c}')
print(f'd = {d} its a even number')
print(f'e = {e} its a odd number')
print(f'f = {f} its a even number')
# Out:
# a = 32
# b = 7
# c = 55
# d = 0 its a even number
# e = 1 its a odd number
# f = 0 its a even number

# %%
"""
The modulo operator is "%"
The remainder is the amount left over after division. 

If the number is divisible by 2 and the remainder is 0, then the number is even.
If the number is divisible by 2 and the remainder is 1, then the number is odd.

to check the code, we use the == operator, that checks if two values are equal.
Ex.: result == 0 ask "Is result equal to 0?"

"""

a = 10 + 2
b = 23 - 7
result = a % b # 12 % 16

# Para verificar se eh par, dividimos por 2 e verificamos se o resto eh 0
is_even = result % 2 == 0 # 12 % 2 = 0. 0 eh igual ao 0, ent o resultado eh True

print(f'a = {a}')
print(f'b = {b}')
print(f'result = {result}') # the result is 12 becouse 16 cant fit in 12, so the remainder is 12
print(f'is_even = {is_even}')
# Out:
# a = 12
# b = 16
# result = 12
# is_even = True

# %%
# Type your code below
x = 15
y = 4
z = 23

w = x % y
v = z % x
u = z % y

# Don't change the line below
print(f"x = {x}")
print(f"y = {y}")
print(f"z = {z}")
print(f"w = {w}")
print(f"v = {v}")
print(f"u = {u}")
# Out:
# x = 15
# y = 4
# z = 23
# w = 3
# v = 8
# u = 3

# %% [markdown]
# # Arithmetrics Shortcuts

# %%
a = 9
a = a + 8 # a holds 17
print(a)

# mas podemos usar +=

b = 9
b += 8
print(b) 

c = 11
c -= 12
print(c)

d = 7 
d *= 8

e = 9
e /= 3

f = 5
f %= 7
print([a,b,c,d,e,f])


# g += 5 vai gerar erro pq ela n foi definida antes
print(g)
# Out:
# 17
# 17
# -1
# [17, 17, -1, 56, 3.0, 5]
# 7

# %% [markdown]
# # Comparison Operations
# """
# Basicly comparison operators are use to compare between two operands.
#
# | Operator | Meaning | Example |
# | --- | --- | --- |
# | == | Equal | `1 == 2` returns false |
# | != | Not Equal | `1 != 2` returns true |
# | > | Greater Than | `1 > 2` returns false |
# | < | Less Than | `1 < 2` returns true |
# | >= | Greater Than or Equal | `1 >= 2` returns false |
# | <= | Less Than or Equal | `1 <= 2` returns true |
#
# ! =      significa que o operador de comparacao fala que nao sao iguais
#
# The `==` operator compares two values for equality, while `=` is the assignment operator. Using `=` in a comparison context would cause an error.
#
# """

# %%
"""
Challenge

Beginner
Write a script that initializes 2 variables n1 and n2 with the values 8 and 9 (accordingly).

After that initialize another variable n3 that will hold whether n1 is bigger than n2.
"""

n1 = 8 
n2 = 9
n3 = n1 > n2
print(f"n1 = {n1}, n2 = {n2}, n3 = {n3}")
# Out:
# n1 = 8, n2 = 9, n3 = False

# %%
pwd

# %% [markdown]
# # Logical Operators 1

# %%
# o and retorna True se realmente os argumentos são de verdade

# criar duas variaveis booleanas
a = True
b = True

# checar se a e b sao verdadeiras 
c = a and b
print(c)

d = True
e = False

f = d and e

g = False
h = False

# The and operator only returns True when both operands are True; any other combination returns False.
i = g and h

print([c,f,i])
# Out:
# True
# [True, False, False]

# %%
"""
Complete the code to determine if a person is eligible to drive based on their age and license status.

A person is eligible to drive when:

They are at least 18 years old AND
They have a valid driving license
Fill in the blanks with the correct values:

Fill in the age variable with 20
Fill in the has_license variable with True
Fill in the minimum age requirement in the comparison
"""

age = 20
has_license = True

result = age >= 18 and has_license

print("O estudante esta habilitado: ", result)
# Out:
# O estudante esta habilitado:  False

# %%
# Criei duas variaveis
valor_1 = 20
valor_2 = 13

# vou dizer que esta variavel eh verdadeira
terceira_variavel = True

# os valores entre valor_1 e valor_2 tem que ser nao iguais para retornar True
resultado = valor_1 != valor_2 and terceira_variavel
# o valor booleano eh verdadeiro neste caso do valor_1 e valor_2 ent eh True e a terceira variavel eh True
# ent o True and True tem que retornar True
print("Variavel esperada seja True: ", resultado)
# Out:
# Variavel esperada seja True:  True

# %%
# Crie duas variáveis booleanas com valores diferentes e use o operador and para 
# verificar o resultado em uma terceira variável, dizendo qual valor você espera que seja armazenado nela.

bradesco = True
itau = False

mesmo_banco = bradesco and itau
print("Sao mesmos bancos? ", mesmo_banco)
# Out:
# Sao mesmos bancos?  False

# %%
"""
Contexto: Você está desenvolvendo um sistema de controle de acesso para uma área restrita. 
Para que a entrada seja autorizada, o funcionário precisa cumprir duas regras simultaneamente: possuir crachá 
ativo e ter liberação do supervisor.

Atividade: Crie duas variáveis booleanas com valores diferentes entre si 
(crachá_ativo e liberado_supervisor). Em seguida, utilize o operador and para verificar o acesso em 
uma terceira variável chamada acesso_permitido e informe qual valor final você espera que seja armazenado nela, 
justificando o motivo.
"""

cracha_ativo = False
liberado_supervisor = True

acesso_permitido = cracha_ativo and liberado_supervisor

print("Acesso: ", acesso_permitido)
# Out:
# Acesso:  False

# %%
"""
Contexto: Em um sistema de automação residencial, uma lâmpada inteligente só pode acender se três condições 
de segurança e ambiente forem atendidas ao mesmo tempo: o sensor de presença deve detectar movimento, 
o modo noturno deve estar ativado, e o sistema de alarme não pode estar disparado (ou seja, o alarme armado 
deve ser False para essa condição específica, mas para simplificar com o and, pense que a condição de 
"segurança OK" precisa ser verdadeira). Vamos lá: considere três variáveis booleanas: presenca_detectada = True, 
modo_noturno = True e sistema_seguro = False.

Atividade: Utilize o operador and para combinar essas três variáveis em uma única verificação que define a 
variável lampa_acesa. Informe qual valor final você espera que seja armazenado nela e explique o 
porquê com base na regra do operador and.
"""
presenca_detectada = True
modo_noturno = True
sistema_seguro = False

lampada_acesa = presenca_detectada and modo_noturno and sistema_seguro
print("Lampada foi acesa: ", lampada_acesa)
# Out:
# Lampada foi acesa:  False
