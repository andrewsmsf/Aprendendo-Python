# %% [markdown]
# # Opencode - Deep Seek A01

# %%
"""
Boa! Aqui vai um exercício progressivo pra você praticar os operadores aritméticos (+, -, *, /, //, %, **).
Nível 1 — Decoreba dos operadores
Preencha o que cada operador faz:

"""
print(10 + 3)    # 13 soma
print(10 - 3)    # 7 subtracao
print(10 * 3)    # 30 multiplicacao
print(10 / 3)    # 3.33 resultado com decimal
print(10 // 3)   # 3 divisão inteira (resultado sem .5)
print(10 % 3)    # 1 resto da divisão
print(10 ** 3)   # 1000 potência
# Rode e confira. Depois responda mentalmente: o que diferencia / de // e %?
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
# Nível 2 — Seu projeto de gastos (use isso de verdade!)
# Escreva um script que simule seu controle de gastos mensal:

salario = 3500.00
aluguel = 1200.00
alimentacao = 650.50
transporte = 280.00
lazer = 400.00
emergencia = 150.20

total = aluguel + alimentacao + transporte + lazer + emergencia
sobrou = salario - total

print("Seu salario eh: R$", salario)
print("Você gastou: R$", total)
print("Sobra: R$", sobrou)
print("Quantas vezes seu gasto total 'cabe' no salario? ", int(salario // total)) # neste caso aqui o operador // ele vai fazer a divisao inteira do divisor mas vai dar o resultado final como inteiro
print("Qual o percentual do salario vai para o aluguel? ", (aluguel / salario)* 100, "%")

""" 
Depois responda:
- Se você quisesse dividir a sobra igualmente entre 2 metas, quanto daria (com decimais)? → sobrou / 2
- Quantas vezes seu gasto total "cabe" no salário (inteiro)? → salario // total
- Qual o percentual do salário que vai pra aluguel? → (aluguel / salario) * 100

"""
pass
# Regra do Jupyter: Se a última linha de uma célula for um valor ou expressão solta (que não foi armazenada em uma variável), ele pega esse valor e exibe na tela como o resultado (Out) da célula.
# Out:
# Seu salario eh: R$ 3500.0
# Você gastou: R$ 2680.7
# Sobra: R$ 819.3000000000002
# Quantas vezes seu gasto total 'cabe' no salario?  1
# Qual o percentual do salario vai para o aluguel?  34.285714285714285 %

# %%
"""
Nível 3 — Bonus "cripto" (tem a ver com o que você curte)
"""
preco_btc = 300000.00      # um valor hipotético
pix_fraude = 0.5           # quantos BTC você tem

# Calcule QUANTO vale em R$
total = preco_btc * pix_fraude
print("BTC",total)

# Depois, descubra quanto resta se você pagar uma taxa de 2% (use % e /)
taxa = total * 2 / 100
print("Taxa: BTC", taxa)
print("Líquido: BTC", total - taxa)
# Regra do jogo: não copie e cole — digite na mão, rode, e me diga o que apareceu em cada print. Me manda o resultado (ou prints de erro) e eu te dou o próximo exercício.
# Out:
# BTC 150000.0
# Taxa: BTC 3000.0
# Líquido: BTC 147000.0
