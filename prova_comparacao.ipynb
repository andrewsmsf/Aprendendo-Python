# %% [markdown]
# # Prova Operadores de Comparacao - A01

# %% [markdown]
# Perfeito. Aqui está sua prova — só com as instruções, sem código. Você escreve tudo do seu jeito e me manda o notebook/colagem pra eu avaliar.
# PROVA — Operadores de Comparação
# Cabeçalho
# - Nome do arquivo: prova_comparacao.ipynb
# - Conteúdo avaliado: operadores ==, !=, >, <, >=, <=
# - Regras:
# - Você pode usar variáveis e comentários, mas apenas os operadores acima (proibido criar funções, listas, loops ou importar coisas).
# - Cada exercício deve usar pelo menos um operador de comparação.
# - Nomes de variáveis devem ser descritivos (ex: idade, saldo_minimo, não a, x).
# - Cada exercício pode ter um comentário explicando sua intenção.
# Exercícios (6)
# 1. Maioridade — Crie uma variável idade com um valor de sua escolha. Determine se a pessoa é maior de idade (>= 18). O resultado (True/False) deve ser a última expressão da célula.
# 2. Jogo de acerto — Crie duas variáveis: numero_secreto e palpite, com valores diferentes entre si. Verifique se o palpite é igual ao número secreto.
# 3. Orçamento apertado — Crie salario e gasto_total (use valores realistas). Verifique se a pessoa não estourou o orçamento (gasto <= salario).
# 4. Desconto ou não? — Crie valor_compra e limite_desconto. Verifique se o valor da compra ultrapassa o limite para ganhar desconto.
# 5. Senha correta? — Crie senha_cadastrada e senha_digitada (textos, use aspas). Verifique se diferem — ou seja, se a senha está errada.
# 6. Percentual de meta — Crie meta_mensal e valor_alcancado. Verifique se o valor alcançado é maior ou igual à meta, mas também verifique se é estritamente menor que a meta. Use duas comparações separadas.
# Critérios avaliativos (o que eu vou checar)
# Critério
# Usou os 6 operadores (==, !=, >, <, >=, <=) pelo menos uma vez
# Nomes de variáveis descritivos em todos os exercícios
# Apenas os operadores permitidos (sem print, listas, etc.)
# Código roda sem erro (SyntaxError/NameError)
# Pelo menos um comentário explicativo
# Total: 16 pontos.

# %%
# 1. Maioridade — Crie uma variável idade com um valor de sua escolha. Determine se a pessoa é maior de idade (>= 18). O resultado (True/False) deve ser a última expressão da célula.

print("Descubra se voce eh maior de idade.")
idade = None
idade = input("Sua idade: ")
maior_idade = True
menor_idade = False

if (int(idade) >= 18):{
    print(f'Voce tem {idade} anos, MAIOR de idade {maior_idade}')
}
else: { 
    print(f'Voce tem {idade} anos, MENOR de idade {menor_idade}')
}
# Out:
# Descubra se voce eh maior de idade.
# Voce tem 22 anos, MAIOR de idade True

# %%
# correcao da 1
"""
Chaves estilo C no exercício 1: if (idade >= 18):{ — funciona por acaso, mas Python não usa chaves pra bloco. O correto é só : + indentação:
if idade >= 18:
    print(...)    

"""
print("Descubra se voce eh maior de idade.")
idade = None
idade = input("Sua idade: ")
maior_idade = True
menor_idade = False

if int(idade) >= 18:{
    print(f'Voce tem {idade} anos, MAIOR de idade {maior_idade}')
}
else: { 
    print(f'Voce tem {idade} anos, MENOR de idade {menor_idade}')
}

# %%
# 2. Jogo de acerto — Crie duas variáveis: numero_secreto e palpite, com valores diferentes entre si. Verifique se o palpite é igual ao número secreto.
numero_secreto = 20

palpite = input("Veja se seu numero posto eh igual ao numero secreto: ")
resultado = palpite == numero_secreto

print(f'resultado de palpite eh igual ao numero_secreto? {resultado}')
# palpite vem do input como texto ("20"), e você comparou com o número 20. Texto nunca é igual a número → sempre False. Para comparar igual, precisa converter: palpite = int(input(...)).
# Out:
# resultado de palpite eh igual ao numero_secreto? False

# %%
# correcao da 2 
numero_secreto = 20

palpite = int(input("Veja se seu numero posto eh igual ao numero secreto: "))
resultado = palpite == numero_secreto

print(f'resultado de palpite eh igual ao numero_secreto? {resultado}')
# Out:
# resultado de palpite eh igual ao numero_secreto? True

# %%
# 3. Orçamento apertado — Crie salario e gasto_total (use valores realistas). Verifique se a pessoa não estourou o orçamento (gasto <= salario).
salario = None
aluguel = 1210.55
comida = 532.99
luz = 320.20
internet = 175.50

print("Bem-vindo a sua calculadora de orcamento.\n")
print(f'Seu aluguel: R${aluguel}')
print(f'Gastos com comida: R${comida}')
print(f'Gastos com luz: R${luz}')
print(f'Gastos com internet: R${internet}')
salario = float(input("Qual seu salario? R$"))

gasto_total = aluguel + comida + luz + internet
lucro = salario - gasto_total

print(f'\nSeu salario = R${salario}')
print(f'Seu gasto total: R${gasto_total}')

if (gasto_total <= salario): 
    print("\nParabens voce nao estorou esse mes, lucro de R$", lucro)
    print(f'Quantas vezes o gasto cabe dentro do seu salario? {salario / gasto_total}')
else:
    print("\nVoce estorou o orcamento. Falta: R$", gasto_total - salario)
# Out:
# Bem-vindo a sua calculadora de orcamento.
#
# Seu aluguel: R$1210.55
# Gastos com comida: R$532.99
# Gastos com luz: R$320.2
# Gastos com internet: R$175.5
#
# Seu salario = R$1600.0
# Seu gasto total: R$2239.24
#
# Voce estorou o orcamento. Falta: R$ 639.2399999999998

# %%
# 4. Desconto ou não? — Crie valor_compra e limite_desconto. Verifique se o valor da compra ultrapassa o limite para ganhar desconto.
valor_compra = float(input("Qual valor de compra do produto que escolheu? R$"))

limite_desconto = 150.0

if (valor_compra <= limite_desconto):
    print(f'Parabens vc esta apto para a compra pois o valor da compra nao excedeu o limite {limite_desconto}')
    print(f'O preco da compra foi R$ {valor_compra}')
else:
    print(f'Voce excedeu o limie, o limite eh R${limite_desconto} e o preco da compra foi R${valor_compra}')
# Out:
# Parabens vc esta apto para a compra pois o valor da compra nao excedeu o limite 150.0
# O preco da compra foi R$ 140.0

# %% [markdown]
# Nota: 10/16 ✅ — a matemática e a lógica básica estão certas, mas você escapou de alguns critérios
#
# - Exercício 4 devia usar > ("ultrapassa o limite"). Você usou <= — lógica invertida.
# - Exercício 5 devia usar != (senha errada = diferente). Foi aqui que você travou.
# - Exercício 6 devia ter também o < (estritamente menor).
# Como fazer o != (a parte que você não sabia)
# A lógica é o oposto do ==. No seu exercício 5, em vez de guardar senha_digitada == senha_digitada2 numa variável e comparar de novo, seria:
# senha_cadastrada = "abc123"
# senha_digitada = "abc123"
#
# senha_errada = senha_digitada != senha_cadastrada   # False, senha bateu
# O != responde True quando os valores são diferentes. Se as senhas fossem diferentes, daria True — "está errada". Simples assim.
# 3 coisas pra corrigir (importante pra evolução)
# 1. Chaves estilo C no exercício 1: if (idade >= 18):{ — funciona por acaso, mas Python não usa chaves pra bloco. O correto é só : + indentação:
# if idade >= 18:
#     print(...)
# 2. Bug real no exercício 2: palpite vem do input como texto ("20"), e você comparou com o número 20. Texto nunca é igual a número → sempre False. Para comparar igual, precisa converter: palpite = int(input(...)).
# 3. if senha_cadastrada == True: → em Python, só escreva if senha_cadastrada:. O == True é redundante (mas entendo que você estava praticando o == 😄).
# Boa evolução! O importante é que tudo rodou. Quer que eu faça a recuperação dessa prova só com os 3 operadores que faltaram (!=, >, <) pra fechar os 16 pontos?

# %%
#5. Senha correta? — Crie senha_cadastrada e senha_digitada (textos, use aspas). Verifique se diferem — ou seja, se a senha está errada.
print("Bem vindo ao sistema de senha. Objetivo apenas fazer a verificacao da senha 2 vezes.\nUse caracteres 'Hs_~!#.,' ")
senha_digitada = str(input("Digite sua senha: "))
senha_digitada2 = str(input("Digite sua senha novamente: "))

senha_cadastrada = senha_digitada == senha_digitada2

if (senha_cadastrada == True):
    print(f'Sua senha esta correta!')
else:
    print(f'Sua senha esta errada.')
# Out:
# Bem vindo ao sistema de senha. Objetivo apenas fazer a verificacao da senha 2 vezes.
# Use caracteres 'Hs_~!#.,'
# Sua senha esta correta!

# %%
# correcao da 5

"""
Como fazer o != (a parte que você não sabia)
A lógica é o oposto do ==. No seu exercício 5, em vez de guardar senha_digitada == senha_digitada2 numa variável e comparar de novo, seria:
senha_cadastrada = "abc123"
senha_digitada = "abc123"

senha_errada = senha_digitada != senha_cadastrada   # False, senha bateu
O != responde True quando os valores são diferentes. Se as senhas fossem diferentes, daria True — "está errada". Simples assim.

"""
print("Bem vindo ao sistema de senha. Objetivo apenas fazer a verificacao da senha 2 vezes.\nUse caracteres 'Hs_~!#.,' ")
senha_cadastrada = input("Digite sua senha: ")
senha_digitada = input("Digite sua senha novamente: ")

senha_errada = senha_cadastrada != senha_digitada # o '!=" daria True quando os valores fosse diferentes

print(f'Sua senha esta errada? {senha_errada}')
# Out:
# Bem vindo ao sistema de senha. Objetivo apenas fazer a verificacao da senha 2 vezes.
# Use caracteres 'Hs_~!#.,'
# Sua senha esta errada? True

# %%
# 6. Percentual de meta — Crie meta_mensal e valor_alcancado. Verifique se o valor alcançado é maior ou igual à meta, mas também verifique se é estritamente menor que a meta. Use duas comparações separadas.
meta_mensal = int(input("Quantas metas voce quer tentar bater este mes? "))
valor_alcancado = int(input("Quantas voce conseguiu neste mes? "))


if(valor_alcancado >= meta_mensal):
    print(f'Parabens voce conseguiu acancar a meta de {valor_alcancado}/{meta_mensal}')
else:
    print(f'Voce esta abaixo da meta {valor_alcancado}/{meta_mensal}')
# Out:
# Parabens voce conseguiu acancar a meta de 31/30

# %%
# correcao da 6

meta_mensal = int(input("Quantas metas voce quer tentar bater este mes? "))
valor_alcancado = int(input("Quantas voce conseguiu neste mes? "))


if valor_alcancado >= meta_mensal:
    print(f'Parabens voce conseguiu acancar a meta de {valor_alcancado}/{meta_mensal}')
else:
    abaixo = valor_alcancado < meta_mensal
    print(f'Voce esta abaixo da meta {abaixo}')
# Out:
# Parabens voce conseguiu acancar a meta de 7/7

# %% [markdown]
# # Provinha testar conhecimentos com Gemini 3.5 Flash Lite

# %% [markdown]
# ### Exercício 1: Nomes de Variáveis e Tipos de Dados
# Corrija o código abaixo aplicando as regras de Naming Conventions (Snake Case) do Python e crie as variáveis solicitadas:
# 1. Uma variável que armazena o nome de um jogador (player_name), contendo a string "Carlos".
# 2. Uma variável que armazena a pontuação inicial do jogador como vazia usando o conceito de Empty Variables (score).
# 3. Uma variável booleana indicando se o jogo está ativo (is_active), com valor True.

# %%
player_name = "Carlos"
score = None
is_active = True

# %% [markdown]
# ### Exercício 2: Operador Módulo (%) e Números Pares/Ímpares
# Escreva um código em Python que:
# 1. Declare uma variável chamada numero com o valor 27.
# 2. Utilize o operador de módulo (%) para verificar se o número é ímpar, armazenando o resultado da comparação (== 1) em uma variável booleana chamada is_odd.
# 3. Imprima o valor de is_odd.

# %%
numero = 27
is_odd = numero % 2 == 1 # 27 / 2 = 13,5 | 13 * 2 = 26 e 26 -27 = 1 ||| 1 == 1 True
print(is_odd)
# Out:
# True

# %% [markdown]
# ### Exercício 3: Atalhos Aritméticos (+=, *=)
# Dado o código abaixo, calcule mentalmente (ou escreva e teste) os valores finais das variáveis:
#
# pontos = 10
#
# pontos += 5
#
# pontos *= 2
#
# pontos -= 4
#
# Qual será o valor final impresso se fizermos print(pontos)?

# %%
pontos = 10 # valor inicial
pontos += 5 # 10 + 5 = 15
pontos *= 2 # 15 * 2 = 30
pontos -= 4 # 30 - 4 = 26
# valor final é 26

# %% [markdown]
# ### Exercício 4: Operadores Lógicos (and, or, not)
#
# Analise a expressão lógica abaixo e determine se a variável acesso_permitido será True ou False:
#
# tem_cartao = True
#
# tem_senha = False
#
# biometria_valida = True
#
# acesso_permitido = (tem_cartao and tem_senha) or biometria_valida
#
# Explique brevemente por que o resultado final é esse com base nas tabelas verdade de and e or.

# %%
tem_cartao = True
tem_senha = False
biometria_valida = True

acesso_permitido = (tem_cartao and tem_senha) or biometria_valida # tem_cartao and tem_senha = False | True or biometria_valida = True
print(acesso_permitido)
# Out:
# True

# %% [markdown]
# ### Exercício 5: Desafio Integrado (Simulação de Sistema)
#
# Crie um pequeno script em Python que atenda aos seguintes requisitos baseados no seu estudo:
#
# 1. Crie uma variável nome_produto inicializada com None (indicando que nenhum produto foi cadastrado ainda).
#
# 2. Atribua a string "Teclado Mecânico" à variável nome_produto.
#
# 3. Crie uma variável quantidade com o valor 5 e utilize um atalho aritmético (+=) para somar mais 3 unidades ao estoque.
#
# 4. Crie uma variável booleana chamada tem_estoque que verifique se a quantidade final é maior que 0 usando operadores de comparação.
#
# 5. Imprima uma frase utilizando f-string mostrando o nome do produto, a quantidade final e se tem estoque.

# %%
nome_produto = None
nome_produto = input()
quantidade = 5 
quantidade += 3
tem_estoque = quantidade > 0

print(f'Seu produto {nome_produto} tem no nosso estoque: {tem_estoque}')
# Out:
# Seu produto Teclado Mecânico tem no nosso estoque: True
